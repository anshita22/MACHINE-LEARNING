# %% [markdown]
# <a href="https://colab.research.google.com/github/anshita22/MACHINE-LEARNING/blob/main/linear_neural_net.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow==2.0.0-alpha0
# Out:
# ...
#      |████████████████████████████████| 80.3MB 69kB/s
# ...
#      |████████████████████████████████| 419kB 39.4MB/s
# ...
#      |████████████████████████████████| 51kB 3.7MB/s
# ...
#      |████████████████████████████████| 3.0MB 50.7MB/s
# ...
#   Found existing installation: tensorflow 2.4.1
#     Uninstalling tensorflow-2.4.1:
#       Successfully uninstalled tensorflow-2.4.1
# ...

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np

# %%
model = keras.Sequential([keras.layers.Dense(units=1, input_shape= [1])])

# %%
model.compile(optimizer='sgd', loss= 'mean_squared_error')

# %%
xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype = float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype = float)

# %%
model.fit(xs, ys, epochs = 500)
print(model.predict([10.0]))
# Out:
# Epoch 1/500
# 6/6 [==============================] - 0s 9ms/sample - loss: 3.1953
# Epoch 2/500
# 6/6 [==============================] - 0s 457us/sample - loss: 3.1403
# Epoch 3/500
# 6/6 [==============================] - 0s 333us/sample - loss: 3.0864
# Epoch 4/500
# 6/6 [==============================] - 0s 393us/sample - loss: 3.0337
# Epoch 5/500
# 6/6 [==============================] - 0s 316us/sample - loss: 2.9821
# Epoch 6/500
# 6/6 [==============================] - 0s 367us/sample - loss: 2.9317
# Epoch 7/500
# 6/6 [==============================] - 0s 359us/sample - loss: 2.8823
# Epoch 8/500
# 6/6 [==============================] - 0s 329us/sample - loss: 2.8341
# Epoch 9/500
# 6/6 [==============================] - 0s 359us/sample - loss: 2.7869
# Epoch 10/500
# 6/6 [==============================] - 0s 331us/sample - loss: 2.7407
# Epoch 11/500
# 6/6 [==============================] - 0s 333us/sample - loss: 2.6955
# Epoch 12/500
# ...
